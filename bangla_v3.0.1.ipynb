# %% [markdown]
# <a href="https://colab.research.google.com/github/mbbipul/AlgorithmImplementation_C/blob/master/bangla_v3.0.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# # Bengali Character Generator

# %%
# !sudo pip3 install Pillow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -a "/content/drive/My Drive/bengalifonts/." /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf

# %%
# !cp -a "/content/drive/My Drive/bengalifonts/." /usr/share/fonts/truetype

# %%
import matplotlib as mpl
mpl.font_manager._rebuild()

# %%
# !sudo apt-get install libfreetype6-dev libharfbuzz-dev libfribidi-dev gtk-doc-tools

# %%
# !sudo ldconfig

# %%
# !sudo apt install fonts-indic

# %%
#get_ipython().system_raw("unrar x fontsbb.rar")

# %%
# !unzip selection

# %%
mkdir data

# %%
from PIL import Image, ImageFont, ImageDraw
def save_image(text,name,font): 
  im = Image.new("RGB",(64, 64))
  draw = ImageDraw.Draw(im)

  asdf = ImageFont.truetype(font,30)
  draw.text((20, 15), text, font=asdf)
  im.save(name+".jpg")

# %%
save_image("ক্ষ","bipul33",'/content/16-December.ttf')

# %%
bangla_char

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d6aa0081-01c5-412f-8878-0c8cc7172250" name="files[]" multiple disabled />
#      <output id="result-d6aa0081-01c5-412f-8878-0c8cc7172250">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving selection.zip to selection.zip

# %%
import tensorflow as tf

# %%
mkdir dataen‌‌‌‌‌

# %%
# !unzip data #-d /content/datapics/

# %%
# Just needed in case you'd like to append it to an array
import os
font_name = []
path_to_fonts = "/content/drive/My Drive/selection"
for filename in os.listdir(path_to_fonts):
    if filename.endswith("ttf") | filename.endswith("TTF"): 
        # Your code comes here such as 
        font_name.append(filename)

# %%
len(font_name)
# Out:
# 338

# %%
def get_filenames_from_folder(folder_path):
  data = []
  for filename in os.listdir(folder_path):
        data.append(int(''.join(filter(str.isdigit, filename))))
  return data

# %%
res = get_filenames_from_folder("/content/data")
resen = get_filenames_from_folder("/content/dataen")

# %%
res

# %%
len(res)
# Out:
# 64

# %%
# !zip -r "myfilesen.zip" /content/dataen

# %%
for i in range(len(data)):
  save_image("k","dataen/"+str(i),"/content/selection/"+data[i])
  # time.sleep(3)

# %%
def get_correct_font(lst):
  rest = []
  for i in range(len(lst)):
    rest.append(data[lst[i]])
  return rest

# %%
resbd = get_correct_font(res)

# %%
resen = get_correct_font(resen)

# %%
len(resen)
# Out:
# 252

# %%
with open('font_input_in_bd.txt', 'w') as f:
    for item in resbd:
        f.write("%s\n" % item)

# %%
mkdir databnafters

# %%
mkdir dataenafterd

# %%
for i in range(len(resen)):
  save_image("h","dataenafterd/"+str(i),"/content/selection/"+resen[i])
  # time.sleep(3)

# %% [markdown]
# #Generate Dataset

# %% [markdown]
# *Read bengali character file and convert to list*

# %%
bangla_char = [line.rstrip('\n') for line in open('bangla_char.txt')]

# %%
bangla_char

# %%
bangla_char_u = ['\u0982','\u0983','\u0981','\u09BE','\u09BF','\u09C0','\u09C1','\u09C2','\u09C3','\u09C4','\u09C7','\u09C8','\u09CB','\u09CC','\u09CD']

# %%
bangla_char.extend(bangla_char_u)

# %%
len(bangla_char)
# Out:
# 72

# %%
bangla_char

# %%
fonts_name = [line.rstrip('\n') for line in open('/content/font_input_in_bd.txt')]

# %%
len(fonts_name)
# Out:
# 64

# %%
from PIL import Image, ImageFont, ImageDraw
import os
W = 64 
H = 64
def save_image(text,name,font): 
  font_size = [10,12,15,18,20,25,30,35,40,45]
  for i in range(len(font_size)):
    im = Image.new("RGB",(64,64))
    draw = ImageDraw.Draw(im)
    bengali_font = ImageFont.truetype(font,font_size[i])
    w, h = bengali_font.getsize(text)
    draw.text(((64-w)/2,(64-h)/2), text, font=bengali_font)
    im.save(name+"_"+str(font_size[i])+".jpg")

# %%
for i in range(len(fonts_name)):
  save_image("ক্ষ",""+str(i),"/content/SutonnyMJ.ttf")

# %%
mkdir testimages

# %%
for i in range(len(bangla_char)):
  folder_name = "/content/drive/My Drive/bangla_basic_characters_dataset_v1.0/class_"+str(bangla_char[i])+"/"
  if not os.path.exists(os.path.dirname(folder_name)):
    try:
        os.makedirs(os.path.dirname(folder_name))
    except OSError as exc: # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise
  count = 0
  for j in range(len(fonts_name)):
    if(count>50):
      save_image(bangla_char[i],folder_name+"img"+str(j),"/content/drive/My Drive/selection/"+fonts_name[j])
    else:
      save_image(bangla_char[i],folder_name+"img"+str(j),"/content/drive/My Drive/selection/"+fonts_name[j])

# %% [markdown]
# **Save image to folder**

# %%
root_folder = "/content/bangla_basic_characters_dataset_V3.0.0/"
train_folder = root_folder + "train/"
test_folder = root_folder + "test/"
valid_folder = root_folder + "valid/"

for i in range(len(bangla_char)):
  class_name = "class_"+str(bangla_char[i])
  class_name_path = "class_"+str(bangla_char[i])+"/"
  train_folder_path = train_folder  + class_name_path
  valid_folder_path = valid_folder  + class_name_path
  test_folder_path = test_folder + "All/"

  if not os.path.exists(os.path.dirname(train_folder_path)):
    try:
        os.makedirs(os.path.dirname(train_folder_path))
        
    except OSError as exc: # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise
  if not os.path.exists(os.path.dirname(valid_folder_path)):
    try:
        os.makedirs(os.path.dirname(valid_folder_path))
        
    except OSError as exc: # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise
  if not os.path.exists(os.path.dirname(test_folder_path)):
    try:
        os.makedirs(os.path.dirname(test_folder_path))
        
    except OSError as exc: # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise

  count = 0
  for j in range(len(fonts_name)):
    if ((count > 45) & (count<=55)):
      save_image(bangla_char[i],valid_folder_path+"/"+class_name+"_img"+str(j),"/content/drive/My Drive/selection/"+fonts_name[j])
    elif (count > 55 )  :
      save_image(bangla_char[i],test_folder_path+class_name+"_img"+str(j),"/content/drive/My Drive/selection/"+fonts_name[j])
    else:
      save_image(bangla_char[i],train_folder_path+"/"+class_name+"_img"+str(j),"/content/drive/My Drive/selection/"+fonts_name[j])
    count += 1

# %% [markdown]
# #Model

# %% [markdown]
# **Data generator**

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, AvgPool2D
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np
import glob
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
root_path = "/content/bangla_basic_characters_dataset_V3.0.0/"
train_path = root_path + "train/"
test_path = root_path + "test/"
valid_path = root_path + "valid/"
dim = 64
batch_size = 12

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

valid_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    directory=train_path,
    target_size=(dim, dim),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True,
    seed=42
)
# Out:
# Found 33120 images belonging to 72 classes.

# %%
valid_generator = valid_datagen.flow_from_directory(
    directory=valid_path,
    target_size=(dim, dim),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True,
    seed=42
)
# Out:
# Found 7200 images belonging to 72 classes.

# %%
test_generator = test_datagen.flow_from_directory(
    directory=test_path,
    target_size=(dim, dim),
    color_mode="grayscale",
    batch_size=1,
    class_mode=None,
    shuffle=False,
    seed=42
)
# Out:
# Found 5760 images belonging to 1 classes.

# %% [markdown]
# **Build Model**

# %%
def build_model():
  model = Sequential()

  model.add(Conv2D(112, kernel_size=3, activation='relu', input_shape=(64,64,1)))
  model.add(Conv2D(64, kernel_size=3, activation='relu'))
  model.add(AvgPool2D(pool_size=(2,2),strides=(2,2)))
  model.add(Dropout(0.25))
  # model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
  #                 activation ='relu'))
  # model.add(AvgPool2D(pool_size=(2,2)))
  
  # model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
  #                 activation ='relu'))
  # model.add(AvgPool2D(pool_size=(2,2)))
  model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                  activation ='relu'))
  model.add(AvgPool2D(pool_size=(2,2), strides=(2,2)))
  model.add(Dropout(0.25))



  model.add(Flatten())

  model.add(Dense(72, activation='softmax'))
  return model

# %%
model = build_model()

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7 (Conv2D)            (None, 62, 62, 112)       1120
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 60, 60, 64)        64576
# _________________________________________________________________
# average_pooling2d_5 (Average (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 30, 30, 32)        18464
# _________________________________________________________________
# average_pooling2d_6 (Average (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 15, 15, 32)        0
# ...

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
checkpointer = ModelCheckpoint(filepath="best_weights_72.hdf5", 
                               monitor = 'val_acc',
                               verbose=1, 
                               save_best_only=True)

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
history = model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    callbacks=[checkpointer],
                    epochs=30)
# Out:
# Epoch 1/30
# 2760/2760 [==============================] - 32s 11ms/step - loss: 2.1352 - acc: 0.4357 - val_loss: 1.1988 - val_acc: 0.6717
#
# Epoch 00001: val_acc improved from -inf to 0.67167, saving model to best_weights_72.hdf5
# Epoch 2/30
# 2760/2760 [==============================] - 31s 11ms/step - loss: 1.0509 - acc: 0.6925 - val_loss: 0.8806 - val_acc: 0.7578
#
# Epoch 00002: val_acc improved from 0.67167 to 0.75778, saving model to best_weights_72.hdf5
# Epoch 3/30
# 2760/2760 [==============================] - 31s 11ms/step - loss: 0.7930 - acc: 0.7623 - val_loss: 0.6470 - val_acc: 0.8138
#
# Epoch 00003: val_acc improved from 0.75778 to 0.81375, saving model to best_weights_72.hdf5
# Epoch 4/30
# 2760/2760 [==============================] - 31s 11ms/step - loss: 0.6604 - acc: 0.7986 - val_loss: 0.6210 - val_acc: 0.8268
#
# Epoch 00004: val_acc improved from 0.81375 to 0.82681, saving model to best_weights_72.hdf5
# Epoch 5/30
# ...

# %%
model.load_weights('best_weights_72.hdf5')

# %%
model.save(root_path+'bengali_ocr_cnn_93194.h5')

# %%
model.evaluate_generator(generator=valid_generator,
steps=STEP_SIZE_VALID)
# Out:
# [0.25358771714094475, 0.9340277817845345]

# %%
STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
test_generator.reset()
pred=model.predict_generator(test_generator,
steps=STEP_SIZE_TEST,
verbose=1)
# Out:
# 5760/5760 [==============================] - 8s 1ms/step

# %%
predicted_class_indices=np.argmax(pred,axis=1)

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]

# %%
predictions

# %%
x= test_generator[1000][0,:, :, 0]
plt.imshow(x, cmap=plt.cm.gray)

# %%
import math
import matplotlib.image as mpimg
from matplotlib import font_manager as fm, rcParams


def show_sample(images, labels, sample_count=25):
  # Create a square with can fit {sample_count} images
  grid_count = math.ceil(math.ceil(math.sqrt(sample_count)))
  grid_count = min(grid_count, len(images), len(labels))
  
  
  fpath = os.path.join(rcParams["datapath"], "/content/drive/My Drive/selection/Sornaly.ttf")
  prop = fm.FontProperties(fname=fpath)
  fname = os.path.split(fpath)[1]

  plt.figure(figsize=(2*grid_count, 2*grid_count))
  for i in range(sample_count):
    plt.subplot(grid_count, grid_count, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.tight_layout()
    img = images[i][0,:, :, 0]
    plt.imshow(img, cmap=plt.cm.gray)
    plt.xlabel(labels[i],fontproperties=prop,fontsize=30)
  plt.show()

# %%
def load_images(folder):
    images = []
    for filename in os.listdir(folder):
        img = mpimg.imread(os.path.join(folder, filename))
        if img is not None:
            images.append(img)
    return images
images = load_images(test_path+"All")

# %%
show_sample(test_generator,[label.split("class_")[1] for label in predictions],100)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 108 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 112 missing from current font.
#   font.set_text(s, 0.0, flags=flags)

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# **Visualizing intermediate activations**

# %%
from keras import models

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 62, 62, 112)       1120
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 60, 60, 32)        32288
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 30, 30, 64)        18496
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 15, 15, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 15, 15, 64)        0
# ...

# %%
layer_outputs = [layer.output for layer in model.layers[:8]] 
# Extracts the outputs of the top 12 layers
activation_model = models.Model(inputs=model.input, outputs=layer_outputs) # Creates a model that will return these outputs, given the model input

# %%
x= test_generator[908][0,:, :, 0]
plt.imshow(x, cmap=plt.cm.gray)

# %%
activations = activation_model.predict(test_generator[908])

# %%
first_layer_activation = activations[0]
print(first_layer_activation.shape)
# Out:
# (1, 62, 62, 112)

# %%
plt.matshow(first_layer_activation[0, :, :, 4], cmap='viridis')

# %% [markdown]
# **Visualize each layers activation**

# %%
layer_names = []
for layer in model.layers[:7]:
    layer_names.append(layer.name) # Names of the layers, so you can have them as part of your plot
    

images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations): # Displays the feature maps
    n_features = layer_activation.shape[-1] # Number of features in the feature map
    size = layer_activation.shape[1] #The feature map has shape (1, size, size, n_features).
    n_cols = n_features // images_per_row # Tiles the activation channels in this matrix
    display_grid = np.zeros((size * n_cols, images_per_row * size))
    for col in range(n_cols): # Tiles each filter into a big horizontal grid
        for row in range(images_per_row):
            channel_image = layer_activation[0,:, :,col * images_per_row + row]
            channel_image -= channel_image.mean() # Post-processes the feature to make it visually palatable
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size, # Displays the grid
                         row * size : (row + 1) * size] = channel_image
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in true_divide
#   app.launch_new_instance()
